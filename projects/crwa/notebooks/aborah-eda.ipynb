# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import datetime
import sys

# %%
results = pd.read_csv('./../../crwa/data/charles_river_samples_interim/results_merged.csv')

# %%
results.head()
# Out:
#           Activity_ID Lab_ID     Date_Collected Time_Collected Site_ID  \
# 0  720160412ROV1DTH01   None  4/12/2016 0:00:00       05:58:00    ROV1
# 1  720160517ROV1DTH01   None  5/17/2016 0:00:00       05:58:00    ROV1
# 2  720160719ROV1DTH01   None  7/19/2016 0:00:00       06:45:00    ROV1
# 3  720160719ROV2DTH01   None  7/19/2016 0:00:00       07:00:00    ROV2
# 4  720160816ROV1DTH01   None  8/16/2016 0:00:00       07:17:00    ROV1
#
#    Project_ID Actual_Result  Actual_Result_Unit_ID Result_Sample_Fraction  \
# 0         7.0          0.67                    5.0                    NaN
# 1         7.0          0.46                    5.0                    NaN
# 2         7.0          0.33                    5.0                    NaN
# 3         7.0           0.5                    5.0                    NaN
# 4         7.0          0.33                    5.0                    NaN
#
#    Reporting_Result  ...  Data_Type_Name Media_Type_Name  \
# ...

# %%
results['Date_Collected'] = pd.to_datetime(results['Date_Collected'])

# %%
results.head()
# Out:
#           Activity_ID Lab_ID Date_Collected Time_Collected Site_ID  \
# 0  720160412ROV1DTH01   None     2016-04-12       05:58:00    ROV1
# 1  720160517ROV1DTH01   None     2016-05-17       05:58:00    ROV1
# 2  720160719ROV1DTH01   None     2016-07-19       06:45:00    ROV1
# 3  720160719ROV2DTH01   None     2016-07-19       07:00:00    ROV2
# 4  720160816ROV1DTH01   None     2016-08-16       07:17:00    ROV1
#
#    Project_ID Actual_Result  Actual_Result_Unit_ID Result_Sample_Fraction  \
# 0         7.0          0.67                    5.0                    NaN
# 1         7.0          0.46                    5.0                    NaN
# 2         7.0          0.33                    5.0                    NaN
# 3         7.0           0.5                    5.0                    NaN
# 4         7.0          0.33                    5.0                    NaN
#
#    Reporting_Result  ...  Data_Type_Name Media_Type_Name  \
# ...

# %%
results.to_csv('./../../crwa/data/charles_river_samples_interim/results_merged.csv',index=False)

# %%
results = pd.read_csv('./../../crwa/data/charles_river_samples_interim/results_merged.csv', parse_dates=[['Date_Collected', 'Time_Collected']])

# %%
results.head()
# Out:
#   Date_Collected_Time_Collected         Activity_ID Lab_ID Site_ID  \
# 0           2016-04-12 05:58:00  720160412ROV1DTH01   None    ROV1
# 1           2016-05-17 05:58:00  720160517ROV1DTH01   None    ROV1
# 2           2016-07-19 06:45:00  720160719ROV1DTH01   None    ROV1
# 3           2016-07-19 07:00:00  720160719ROV2DTH01   None    ROV2
# 4           2016-08-16 07:17:00  720160816ROV1DTH01   None    ROV1
#
#    Project_ID Actual_Result  Actual_Result_Unit_ID Result_Sample_Fraction  \
# 0         7.0          0.67                    5.0                    NaN
# 1         7.0          0.46                    5.0                    NaN
# 2         7.0          0.33                    5.0                    NaN
# 3         7.0           0.5                    5.0                    NaN
# 4         7.0          0.33                    5.0                    NaN
#
#    Reporting_Result  Reporting_Result_Unit_ID  ... Data_Type_Name  \
# ...

# %%
results.to_csv('./../../crwa/data/charles_river_samples_interim/results_merged.csv',index=False)
